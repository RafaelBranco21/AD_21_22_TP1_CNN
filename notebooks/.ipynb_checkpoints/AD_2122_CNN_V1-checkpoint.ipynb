# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
except Exception:
    pass

# TensorFlow ≥2.0 is required
import tensorflow as tf
assert tf.__version__ >= "2.0"

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)


# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %%
from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
import os 

PATH = '.\\..\\dataset\\micro_expressions'
PATH
# Out:
# '.\\..\\dataset\\micro_expressions'

# %%
# Conferir o número total de imagens

import pathlib 

train_dir = os.path.join(PATH, 'train')
test_dir = os.path.join(PATH, 'test')

print(train_dir)
print(test_dir)
# Out:
# .\..\dataset\micro_expressions\train
# .\..\dataset\micro_expressions\test

# %%
import pathlib 

train_dir = pathlib.Path(train_dir)
test_dir = pathlib.Path(test_dir)

image_count = len(list(train_dir.glob('*/*.jpg')))
print(image_count)

image_count = len(list(test_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 6938
# 1700

# %%
# Construção e pré-processamento do Dataset a partir das imagens em disco
# Existem 5 pastas para cada uma das classes
# A informação nas pastas não está dividida em conjuntos de treino e validação
# Consultar detalhes na aula anterior e aqui: https://www.tensorflow.org/tutorials/load_data/images

batch_size = 32
IMG_SIZE = (80, 80)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  train_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  shuffle=True,
  image_size=IMG_SIZE,
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  test_dir,
  validation_split=0.8,
  subset="validation",
  seed=123,
  shuffle=True,
  image_size=IMG_SIZE,
  batch_size=batch_size)

class_names = train_ds.class_names

train_ds = train_ds.cache().prefetch(1)
val_ds = val_ds.cache().prefetch(1)

normalization_layer = keras.layers.experimental.preprocessing.Rescaling(1./255)

train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))
# Out:
# Found 6938 files belonging to 7 classes.
# Using 5551 files for training.
# Found 1700 files belonging to 7 classes.
# Using 1360 files for validation.

# %%
# Obter alguma informação sobre o dataset

#Cardinalidade 
print('Cardinalidade Treino: ', train_ds.cardinality().numpy())
print('Cardinalidade Validacão: ', val_ds.cardinality().numpy())

print('Classes: ', class_names)


# Explicar o valor obtido para a cardinalidade dos conjuntos
# Out:
# Cardinalidade Treino:  174
# Cardinalidade Validacão:  43
# Classes:  ['anger', 'disgust', 'fear', 'happiness', 'neutral', 'sadness', 'surprise']

# %%
# Visualizar algumas imagens do Dataset
plt.figure(figsize=(15, 10))
for images, labels in train_ds.take(1):
    for i in range(10):
        ax = plt.subplot(2, 10, i + 1)
        plt.imshow(images[i].numpy().astype("float32")) #pode ser transformado num array numpy 
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
# Criação de uma CNN
# Crie uma CNN sequencial utilizando a API funcional do Keras, não ultrapassando os 5 milhões de parâmetros
# https://www.tensorflow.org/api_docs/python/tf/keras/Model
# https://www.tensorflow.org/guide/keras/sequential_model
# https://keras.io/api/layers/

# O modelo final deve ter o nome model

keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

# CRIAR NOVO MODELO chamado model utilizando a API funcional

inputs = keras.Input(shape=(80, 80, 3))
x = keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same')(inputs)
x = keras.layers.MaxPooling2D()(x)
x = keras.layers.Conv2D(64, 3, activation='relu',padding='VALID')(x)
x = keras.layers.MaxPooling2D()(x)
x = keras.layers.Conv2D(120, 3, activation='relu',padding='VALID')(x)
x = keras.layers.MaxPooling2D()(x)
x = keras.layers.Flatten()(x)
x = keras.layers.Dense(90, activation='relu')(x)
x = keras.layers.Dropout(0.5)(x)
x = keras.layers.Dense(60, activation='relu')(x)
x = keras.layers.Dropout(0.5)(x)
outputs = keras.layers.Dense(7, activation="softmax")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
# Confirme se cumpriu o limite para o número de parâmteros especificado em cima

model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 80, 80, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 80, 80, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 40, 40, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 38, 38, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 19, 19, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 17, 17, 120)       69240
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 120)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 7680)              0
# _________________________________________________________________
# dense (Dense)                (None, 90)                691290
# _________________________________________________________________
# dropout (Dropout)            (None, 90)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 60)                5460
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 427
# =================================================================
# Total params: 785,809
# Trainable params: 785,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compilar o modelo
# Utilize o otimizador ADAM com parametrização default e a accuracy como métrica
# Defina a função de loss L que considerar mais apropriada

L = keras.losses.SparseCategoricalCrossentropy()

model.compile(loss=L, optimizer="adam", metrics=["accuracy"])

# %%
# Treinar o modelo durante 15 épocas 

history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=100
)

# Começa a ocorrer o overffiting na epoch 6
# Poderia ser adicionado early-stoping
# Out:
# Epoch 1/100
# 174/174 [==============================] - 2s 11ms/step - loss: 1.8347 - accuracy: 0.2578 - val_loss: 1.6530 - val_accuracy: 0.4250
# Epoch 2/100
# 174/174 [==============================] - 2s 9ms/step - loss: 1.6240 - accuracy: 0.3628 - val_loss: 1.4948 - val_accuracy: 0.4772
# Epoch 3/100
# 174/174 [==============================] - 2s 9ms/step - loss: 1.5380 - accuracy: 0.4053 - val_loss: 1.3958 - val_accuracy: 0.5235
# Epoch 4/100
# 174/174 [==============================] - 2s 9ms/step - loss: 1.4500 - accuracy: 0.4552 - val_loss: 1.3106 - val_accuracy: 0.5632
# Epoch 5/100
# 174/174 [==============================] - 2s 9ms/step - loss: 1.3356 - accuracy: 0.5192 - val_loss: 1.2144 - val_accuracy: 0.5882
# Epoch 6/100
# 174/174 [==============================] - 2s 9ms/step - loss: 1.2620 - accuracy: 0.5433 - val_loss: 1.1748 - val_accuracy: 0.5919
# Epoch 7/100
# 174/174 [==============================] - 2s 9ms/step - loss: 1.1964 - accuracy: 0.5740 - val_loss: 1.1081 - val_accuracy: 0.6169
# Epoch 8/100
# 174/174 [==============================] - 2s 9ms/step - loss: 1.1441 - accuracy: 0.5975 - val_loss: 1.0862 - val_accuracy: 0.6169
# Epoch 9/100
# 174/174 [==============================] - 2s 11ms/step - loss: 1.0906 - accuracy: 0.6069 - val_loss: 1.1063 - val_accuracy: 0.6081
# Epoch 10/100
# 174/174 [==============================] - 2s 9ms/step - loss: 1.0383 - accuracy: 0.6370 - val_loss: 1.0259 - val_accuracy: 0.6419
# Epoch 11/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.9866 - accuracy: 0.6458 - val_loss: 0.9992 - val_accuracy: 0.6449
# Epoch 12/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.9246 - accuracy: 0.6656 - val_loss: 0.9629 - val_accuracy: 0.6632
# Epoch 13/100
# 174/174 [==============================] - 2s 10ms/step - loss: 0.8838 - accuracy: 0.6808 - val_loss: 0.9790 - val_accuracy: 0.6588
# Epoch 14/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.8514 - accuracy: 0.6831 - val_loss: 1.0395 - val_accuracy: 0.6360
# Epoch 15/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.8307 - accuracy: 0.6950 - val_loss: 0.9682 - val_accuracy: 0.6750
# Epoch 16/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.7925 - accuracy: 0.7155 - val_loss: 0.9735 - val_accuracy: 0.6721
# Epoch 17/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.7423 - accuracy: 0.7282 - val_loss: 0.9845 - val_accuracy: 0.6912
# Epoch 18/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.7334 - accuracy: 0.7283 - val_loss: 0.9685 - val_accuracy: 0.6941
# Epoch 19/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.7091 - accuracy: 0.7388 - val_loss: 0.9608 - val_accuracy: 0.6868
# Epoch 20/100
# 174/174 [==============================] - 2s 10ms/step - loss: 0.6846 - accuracy: 0.7370 - val_loss: 1.0445 - val_accuracy: 0.6779
# Epoch 21/100
# 174/174 [==============================] - 2s 10ms/step - loss: 0.6580 - accuracy: 0.7512 - val_loss: 0.9929 - val_accuracy: 0.6831
# Epoch 22/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.6583 - accuracy: 0.7469 - val_loss: 1.0016 - val_accuracy: 0.6853
# Epoch 23/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.6300 - accuracy: 0.7629 - val_loss: 1.0632 - val_accuracy: 0.6853
# Epoch 24/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.6001 - accuracy: 0.7678 - val_loss: 1.0359 - val_accuracy: 0.7118
# Epoch 25/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0
100
# 174/174 [==============================] - 2s 10ms/step - loss: 0.2697 - accuracy: 0.9079 - val_loss: 1.9550 - val_accuracy: 0.7228
# Epoch 84/100
# 174/174 [==============================] - 2s 10ms/step - loss: 0.2701 - accuracy: 0.9045 - val_loss: 2.2074 - val_accuracy: 0.7235
# Epoch 85/100
# 174/174 [==============================] - 2s 10ms/step - loss: 0.2663 - accuracy: 0.9040 - val_loss: 2.0243 - val_accuracy: 0.7316
# Epoch 86/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.2751 - accuracy: 0.9027 - val_loss: 2.0172 - val_accuracy: 0.7250
# Epoch 87/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.2852 - accuracy: 0.9024 - val_loss: 2.0512 - val_accuracy: 0.7265
# Epoch 88/100
# 174/174 [==============================] - 2s 10ms/step - loss: 0.2771 - accuracy: 0.9040 - val_loss: 2.0974 - val_accuracy: 0.7154
# Epoch 89/100
# 174/174 [==============================] - 2s 10ms/step - loss: 0.2742 - accuracy: 0.9043 - val_loss: 2.0094 - val_accuracy: 0.7235
# Epoch 90/100
# 174/174 [==============================] - 2s 10ms/step - loss: 0.2698 - accuracy: 0.9063 - val_loss: 2.2841 - val_accuracy: 0.7331
# Epoch 91/100
# 174/174 [==============================] - 2s 12ms/step - loss: 0.2661 - accuracy: 0.9060 - val_loss: 2.3529 - val_accuracy: 0.7412
# Epoch 92/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.2682 - accuracy: 0.9072 - val_loss: 2.3254 - val_accuracy: 0.7272
# Epoch 93/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.2664 - accuracy: 0.9081 - val_loss: 2.0265 - val_accuracy: 0.7257
# Epoch 94/100
# 174/174 [==============================] - 2s 10ms/step - loss: 0.2496 - accuracy: 0.9146 - val_loss: 2.0822 - val_accuracy: 0.7257
# Epoch 95/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.2593 - accuracy: 0.9097 - val_loss: 2.0737 - val_accuracy: 0.7221
# Epoch 96/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.2676 - accuracy: 0.9078 - val_loss: 1.9609 - val_accuracy: 0.7419
# Epoch 97/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.2557 - accuracy: 0.9108 - val_loss: 2.2986 - val_accuracy: 0.7368
# Epoch 98/100
# 174/174 [==============================] - 2s 10ms/step - loss: 0.2416 - accuracy: 0.9179 - val_loss: 2.1572 - val_accuracy: 0.7243
# Epoch 99/100
# 174/174 [==============================] - 2s 10ms/step - loss: 0.2645 - accuracy: 0.9096 - val_loss: 2.1908 - val_accuracy: 0.7287
# Epoch 100/100
# 174/174 [==============================] - 2s 9ms/step - loss: 0.2631 - accuracy: 0.9126 - val_loss: 2.1534 - val_accuracy: 0.7338

# %%
# Visualizar os resultados
# Visualização da evolução da accurary e da loss

import pandas as pd 

history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot();
history_frame.loc[:, ['accuracy', 'val_accuracy']].plot();

# %%
# Adicionar Data Augmentation aos exemplos de treino para combater overfitting
# Consultar os links seguintes para obter detalhes: https://www.tensorflow.org/api_docs/python/tf/keras/layers/experimental/preprocessing
# https://www.tensorflow.org/tutorials/images/data_augmentation


data_augmentation = keras.Sequential([
    keras.layers.experimental.preprocessing.RandomFlip("horizontal",input_shape=(80, 80, 3)),
    keras.layers.experimental.preprocessing.RandomRotation(0.5),
    keras.layers.experimental.preprocessing.RandomZoom(0.25),
])

# %%
plt.figure(figsize=(20, 20))
for images, _ in train_ds.take(1):
    for i in range(16):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("float32"))
        plt.axis("off")

# %%
# Criar modelo com a camada de Data Augmentation - Adicionar como primeira parte do modelo anterior


keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

# O modelo chama-se modelA

inputs2 = keras.Input(shape=(80, 80, 3))
x = data_augmentation(inputs2)
x = keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same')(x)
x = keras.layers.MaxPooling2D()(x)
x = keras.layers.Conv2D(64, 3, activation='relu',padding='VALID')(x)
x = keras.layers.MaxPooling2D()(x)
x = keras.layers.Conv2D(120, 3, activation='relu',padding='VALID')(x)
x = keras.layers.MaxPooling2D()(x)
x = keras.layers.Flatten()(x)
x = keras.layers.Dense(90, activation='relu')(x)
x = keras.layers.Dropout(0.5)(x)
x = keras.layers.Dense(60, activation='relu')(x)
x = keras.layers.Dropout(0.5)(x)
outputs2 = keras.layers.Dense(7, activation="softmax")(x)

modelA = keras.Model(inputs=inputs2, outputs=outputs2)

# %%
modelA.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 80, 80, 3)]       0
# _________________________________________________________________
# sequential (Sequential)      (None, 80, 80, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 80, 80, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 40, 40, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 38, 38, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 19, 19, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 17, 17, 120)       69240
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 120)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 7680)              0
# _________________________________________________________________
# dense (Dense)                (None, 90)                691290
# _________________________________________________________________
# dropout (Dropout)            (None, 90)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 60)                5460
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 427
# =================================================================
# Total params: 785,809
# Trainable params: 785,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compilar e treinar

L = keras.losses.SparseCategoricalCrossentropy()

modelA.compile(loss=L, optimizer="adam", metrics=["accuracy"])

history = modelA.fit(
  train_ds,
  validation_data=val_ds,
  epochs=100
)
# Out:
# Epoch 1/100
# 174/174 [==============================] - 2s 11ms/step - loss: 1.8799 - accuracy: 0.2322 - val_loss: 1.8513 - val_accuracy: 0.2574
# Epoch 2/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.8385 - accuracy: 0.2475 - val_loss: 1.8084 - val_accuracy: 0.2831
# Epoch 3/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.8225 - accuracy: 0.2630 - val_loss: 1.8116 - val_accuracy: 0.2816
# Epoch 4/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.8079 - accuracy: 0.2664 - val_loss: 1.8283 - val_accuracy: 0.2779
# Epoch 5/100
# 174/174 [==============================] - 2s 11ms/step - loss: 1.8025 - accuracy: 0.2652 - val_loss: 1.7871 - val_accuracy: 0.2838
# Epoch 6/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.7872 - accuracy: 0.2776 - val_loss: 1.7885 - val_accuracy: 0.2934
# Epoch 7/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.7931 - accuracy: 0.2765 - val_loss: 1.8080 - val_accuracy: 0.2897
# Epoch 8/100
# 174/174 [==============================] - 2s 9ms/step - loss: 1.7798 - accuracy: 0.2886 - val_loss: 1.7501 - val_accuracy: 0.3419
# Epoch 9/100
# 174/174 [==============================] - 2s 11ms/step - loss: 1.7653 - accuracy: 0.3063 - val_loss: 1.7565 - val_accuracy: 0.3206
# Epoch 10/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.7381 - accuracy: 0.3221 - val_loss: 1.7061 - val_accuracy: 0.3346
# Epoch 11/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.7255 - accuracy: 0.3342 - val_loss: 1.7643 - val_accuracy: 0.3066
# Epoch 12/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.7186 - accuracy: 0.3311 - val_loss: 1.6811 - val_accuracy: 0.3522
# Epoch 13/100
# 174/174 [==============================] - 2s 9ms/step - loss: 1.7073 - accuracy: 0.3318 - val_loss: 1.6587 - val_accuracy: 0.3610
# Epoch 14/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.6890 - accuracy: 0.3311 - val_loss: 1.6677 - val_accuracy: 0.3581
# Epoch 15/100
# 174/174 [==============================] - 2s 13ms/step - loss: 1.6819 - accuracy: 0.3390 - val_loss: 1.6460 - val_accuracy: 0.3625
# Epoch 16/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.6629 - accuracy: 0.3509 - val_loss: 1.6316 - val_accuracy: 0.3676
# Epoch 17/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.6536 - accuracy: 0.3587 - val_loss: 1.6320 - val_accuracy: 0.3551
# Epoch 18/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.6491 - accuracy: 0.3538 - val_loss: 1.6255 - val_accuracy: 0.3743
# Epoch 19/100
# 174/174 [==============================] - 2s 12ms/step - loss: 1.6416 - accuracy: 0.3630 - val_loss: 1.5921 - val_accuracy: 0.3831
# Epoch 20/100
# 174/174 [==============================] - 2s 11ms/step - loss: 1
100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.3162 - accuracy: 0.5082 - val_loss: 1.2445 - val_accuracy: 0.5478
# Epoch 77/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.3232 - accuracy: 0.5077 - val_loss: 1.2709 - val_accuracy: 0.5426
# Epoch 78/100
# 174/174 [==============================] - 2s 11ms/step - loss: 1.3141 - accuracy: 0.5123 - val_loss: 1.2661 - val_accuracy: 0.5287
# Epoch 79/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.3020 - accuracy: 0.5132 - val_loss: 1.2453 - val_accuracy: 0.5360
# Epoch 80/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.2963 - accuracy: 0.5212 - val_loss: 1.2867 - val_accuracy: 0.5331
# Epoch 81/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.3122 - accuracy: 0.5132 - val_loss: 1.2305 - val_accuracy: 0.5507
# Epoch 82/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.3102 - accuracy: 0.5183 - val_loss: 1.2395 - val_accuracy: 0.5324
# Epoch 83/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.3060 - accuracy: 0.5145 - val_loss: 1.2464 - val_accuracy: 0.5397
# Epoch 84/100
# 174/174 [==============================] - 2s 9ms/step - loss: 1.3072 - accuracy: 0.5231 - val_loss: 1.2461 - val_accuracy: 0.5419
# Epoch 85/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.3005 - accuracy: 0.5147 - val_loss: 1.2516 - val_accuracy: 0.5390
# Epoch 86/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.2932 - accuracy: 0.5282 - val_loss: 1.2321 - val_accuracy: 0.5375
# Epoch 87/100
# 174/174 [==============================] - 2s 9ms/step - loss: 1.3016 - accuracy: 0.5132 - val_loss: 1.2457 - val_accuracy: 0.5397
# Epoch 88/100
# 174/174 [==============================] - 2s 9ms/step - loss: 1.2946 - accuracy: 0.5195 - val_loss: 1.2177 - val_accuracy: 0.5419
# Epoch 89/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.2844 - accuracy: 0.5257 - val_loss: 1.2213 - val_accuracy: 0.5507
# Epoch 90/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.2905 - accuracy: 0.5248 - val_loss: 1.2590 - val_accuracy: 0.5419
# Epoch 91/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.2903 - accuracy: 0.5161 - val_loss: 1.2615 - val_accuracy: 0.5397
# Epoch 92/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.2961 - accuracy: 0.5201 - val_loss: 1.2299 - val_accuracy: 0.5478
# Epoch 93/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.2741 - accuracy: 0.5331 - val_loss: 1.2234 - val_accuracy: 0.5463
# Epoch 94/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.2836 - accuracy: 0.5271 - val_loss: 1.1997 - val_accuracy: 0.5618
# Epoch 95/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.2830 - accuracy: 0.5230 - val_loss: 1.1911 - val_accuracy: 0.5515
# Epoch 96/100
# 174/174 [==============================] - 2s 9ms/step - loss: 1.2649 - accuracy: 0.5289 - val_loss: 1.1886 - val_accuracy: 0.5596
# Epoch 97/100
# 174/174 [==============================] - 2s 9ms/step - loss: 1.2683 - accuracy: 0.5392 - val_loss: 1.2028 - val_accuracy: 0.5493
# Epoch 98/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.2867 - accuracy: 0.5296 - val_loss: 1.2161 - val_accuracy: 0.5566
# Epoch 99/100
# 174/174 [==============================] - 2s 10ms/step - loss: 1.2775 - accuracy: 0.5293 - val_loss: 1.2123 - val_accuracy: 0.5596
# Epoch 100/100
# 174/174 [==============================] - 2s 12ms/step - loss: 1.2586 - accuracy: 0.5332 - val_loss: 1.2211 - val_accuracy: 0.5500

# %%
# Visualizar a analisar os resultados
# Visualização da evolução da accurary e da loss

import pandas as pd 

history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['accuracy', 'val_accuracy']].plot()
# Out:
# <AxesSubplot:>

# %%
# Deixou de fazer overffiting
# Com mais epochs iria melhorar ainda mais os resultados

# %%
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['accuracy', 'val_accuracy']].plot()
# Out:
# <AxesSubplot:>
